# %% [markdown]
# <a href="https://colab.research.google.com/github/TasneemBadry/TasneemBadry/blob/main/upload_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('/content/mnist_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
pre=model.predict(x_train[15].reshape(1,28,28))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step

# %%
import numpy as np
pre_class=np.argmax(pre)
pre_class
# Out:
# np.int64(7)

# %%
from tensorflow import keras
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions

# %%
model=VGG16()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %%
img=load_img('/content/cat.jpg',target_size=(224,224))

# %%
img=img_to_array(img)

# %%
img=img.reshape(1,224,224,3)

# %%
pre=model1.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step

# %%
label = decode_predictions(pre)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
img = preprocess_input(img)
# Out:
# tiger_cat (46.18%)

# %%
from keras.applications.resnet50 import ResNet50

# %%
model1=ResNet50()
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# keras.applications have CNN models trained reday to use
